# %% [markdown]
# <a href="https://colab.research.google.com/github/Tebbyrain/tom113b/blob/main/EX03_01_%E5%85%AC%E5%8F%B8%E8%96%AA%E8%B3%87%E6%A6%82%E6%B3%81%E2%85%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Helen", "Ivy", "Jack"],
    "Age": [25, 30, 35, 40, 28, 32, 29, 45, 38, 31],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"],
    "Salary": [50000, 60000, 75000, 65000, 42000, 77000, 62000, 80000, 69000, 71000],
    "Department": ["IT", "HR", "Finance", "Marketing", "IT", "Finance", "Marketing", "IT", "Finance", "Finance"]
}

df = pd.DataFrame(data)

# %%
df[["Name", "Salary"]]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   75000
# 3    David   65000
# 4      Eve   42000
# 5    Frank   77000
# 6    Grace   62000
# 7    Helen   80000
# 8      Ivy   69000
# 9     Jack   71000

# %%
df.iloc[5:8]
# Out:
#     ID   Name  Age          City  Salary Department
# 5  106  Frank   32  Philadelphia   77000    Finance
# 6  107  Grace   29   San Antonio   62000  Marketing
# 7  108  Helen   45     San Diego   80000         IT

# %%
df.iloc[:5]
# Out:
#     ID     Name  Age         City  Salary Department
# 0  101    Alice   25     New York   50000         IT
# 1  102      Bob   30  Los Angeles   60000         HR
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   65000  Marketing
# 4  105      Eve   28      Phoenix   42000         IT

# %%
avg_age = df["Age"].mean()
avg_salary = df["Salary"].mean()
df[(df["Age"] > avg_age) & (df["Salary"] > avg_salary)]
# Out:
#     ID     Name  Age       City  Salary Department
# 2  103  Charlie   35    Chicago   75000    Finance
# 7  108    Helen   45  San Diego   80000         IT
# 8  109      Ivy   38     Dallas   69000    Finance

# %%
print(df["Salary"].mean(), df["Salary"].max(), df["Salary"].min(), df["Salary"].median())
# Out:
# 65100.0 80000 42000 67000.0

# %%
df["Department"].unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Marketing'], dtype=object)

# %%
print(df.groupby("Department")["Salary"].mean().idxmax(), df.groupby("Department")["Salary"].mean().max())
# Out:
# Finance 73000.0

# %%
print(df.groupby("Department")["Age"].mean().idxmin(), df.groupby("Department")["Age"].mean().min())
# Out:
# HR 30.0

# %%
corr_matrix = df[["Age", "Salary"]].corr()
corr_matrix
# Out:
#           Age  Salary
# Age     1.000   0.686
# Salary  0.686   1.000
